# %%
# Importing Required Packages

import numpy as np
import pandas as pd
import sqlite3

# %%
# Read the 'FourDisaster_SouthAsianData2000to2020.csv' as disaster_df

disaster_df = pd.read_csv('FourDisaster_SouthAsianData2000to2020.csv')
disaster_df.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-0009-IRN       No    nat-met-sto-sto        Natural    Meteorological
# 1  2000-0146-BGD       No    nat-met-sto-tor        Natural    Meteorological
# 2  2000-0211-BGD       No    nat-met-sto-tro        Natural    Meteorological
# 3  2000-0229-BGD       No    nat-met-sto-tro        Natural    Meteorological
# 4  2000-0283-BGD       No    nat-met-sto-sto        Natural    Meteorological
#
#   Disaster Type  Disaster Subtype External IDs Event Name  ISO  ...  \
# 0         Storm   Storm (General)          NaN        NaN  IRN  ...
# 1         Storm           Tornado          NaN        NaN  BGD  ...
# 2         Storm  Tropical cyclone          NaN        NaN  BGD  ...
# 3         Storm  Tropical cyclone          NaN        NaN  BGD  ...
# 4         Storm   Storm (General)          NaN        NaN  BGD  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# ...

# %%
# Shape of the data frame

disaster_df.shape
# Out:
# (781, 46)

# %%
# Extract the Year of every row and create a column 'Year'

# Define a function as extract the values

def get_year(entry):
    return entry.split('-')[0]

# Creating the Column 'Year'

disaster_df['Year'] = disaster_df['DisNo.'].apply(get_year)
disaster_df.shape
# Out:
# (781, 47)

# %%
# Connecting the data base with sqlite3

conn = sqlite3.connect(':memory:')
disaster_df.to_sql('DISASTER', conn, index = False)
# Out:
# 781

# %%
# Get the Column Names of the data frame

disaster_df.columns
# Out:
# Index(['DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype',
#        'External IDs', 'Event Name', 'ISO', 'Country', 'Subregion', 'Region',
#        'Location', 'Origin', 'Associated Types', 'OFDA/BHA Response', 'Appeal',
#        'Declaration', 'AID Contribution ('000 US$)', 'Magnitude',
#        'Magnitude Scale', 'Latitude', 'Longitude', 'River Basin', 'Start Year',
#        'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day',
#        'Total Deaths', 'No. Injured', 'No. Affected', 'No. Homeless',
#        'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Reconstruction Costs, Adjusted ('000 US$)',
#        'Insured Damage ('000 US$)', 'Insured Damage, Adjusted ('000 US$)',
#        'Total Damage ('000 US$)', 'Total Damage, Adjusted ('000 US$)', 'CPI',
#        'Admin Units', 'Entry Date', 'Last Update', 'Year'],
#       dtype='object')

# %%
# Running SQL query to select Indian Regions with some specified information

query = 'SELECT Year,Country,ISO,"Disaster Type","Disaster Subtype",Location,"Total Deaths","No. Injured","No. Affected" \
"No. Homeless","Total Affected" FROM DISASTER WHERE Country = "India";'

result = pd.read_sql_query(query, conn)
print('The Shape of the Result Data frame is:', result.shape)
result.head()
# Out:
# The Shape of the Result Data frame is: (276, 9)
#   Country  ISO Disaster Type         Disaster Subtype  \
# 0   India  IND         Storm         Tropical cyclone
# 1   India  IND         Storm         Tropical cyclone
# 2   India  IND         Storm  Lightning/Thunderstorms
# 3   India  IND         Storm         Tropical cyclone
# 4   India  IND         Storm         Tropical cyclone
#
#                                             Location  Total Deaths  \
# 0                            Andhra Pradesh province           NaN
# 1  Nagappattinam, Thanjavur, Sirkali, Papanasam, ...           NaN
# 2                             Uttar Pradesh province          21.0
# 3                            Andhra Pradesh province          78.0
# 4        Gujarat, Goa, Maharashtra, Kerala provinces           NaN
#
#    No. Injured  No. Homeless  Total Affected
# 0          NaN           NaN             NaN
# 1          NaN       30000.0         30000.0
# 2          NaN           NaN             NaN
# ...

# %%
# Export the Data Frame as 'India_Disaster.csv'

file_path = 'India_Disaster.csv'
result.to_csv(file_path, index = False)
