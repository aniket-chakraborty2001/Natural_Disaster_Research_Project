# %%
# Importing required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
# Reading the 'Earthquake_SouthAsianData2000to2020.csv' data
# Store the result in a variable called earth_quake_data

earth_quake_data = pd.read_csv('Earthquake_SouthAsianData2000to2020.csv')
earth_quake_data.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-0023-BGD       No    nat-geo-ear-gro        Natural       Geophysical
# 1  2000-0051-IRN       No    nat-geo-ear-gro        Natural       Geophysical
# 2  2000-0065-IRN       No    nat-geo-ear-gro        Natural       Geophysical
# 3  2001-0033-IND       No    nat-geo-ear-gro        Natural       Geophysical
# 4  2001-0033-PAK       No    nat-geo-ear-gro        Natural       Geophysical
#
#   Disaster Type Disaster Subtype     External IDs  Event Name  ISO  ...  \
# 0    Earthquake  Ground movement  USGS:usp0009khm         NaN  BGD  ...
# 1    Earthquake  Ground movement  USGS:usp0009mz6         NaN  IRN  ...
# 2    Earthquake  Ground movement  USGS:usp0009ne8         NaN  IRN  ...
# 3    Earthquake  Ground movement  USGS:usp000a8ds         NaN  IND  ...
# 4    Earthquake  Ground movement  USGS:usp000a8ds         NaN  PAK  ...
#
# ...

# %%
# Get the Column names of the earth_quake_data

earth_quake_data.columns.values
# Out:
# array(['DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype',
#        'External IDs', 'Event Name', 'ISO', 'Country', 'Subregion',
#        'Region', 'Location', 'Origin', 'Associated Types',
#        'OFDA/BHA Response', 'Appeal', 'Declaration',
#        "AID Contribution ('000 US$)", 'Magnitude', 'Magnitude Scale',
#        'Latitude', 'Longitude', 'River Basin', 'Start Year',
#        'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day',
#        'Total Deaths', 'No. Injured', 'No. Affected', 'No. Homeless',
#        'Total Affected', "Reconstruction Costs ('000 US$)",
#        "Reconstruction Costs, Adjusted ('000 US$)",
#        "Insured Damage ('000 US$)", "Insured Damage, Adjusted ('000 US$)",
#        "Total Damage ('000 US$)", "Total Damage, Adjusted ('000 US$)",
#        'CPI', 'Admin Units', 'Entry Date', 'Last Update'], dtype=object)

# %%
# Get the shape of the earth_quake_data

print('Number of Rows/Recirds in the data frame is:',earth_quake_data.shape[0])
print('Number of Columns/Attributes in the data frame is:',earth_quake_data.shape[1])
# Out:
# Number of Rows/Recirds in the data frame is: 100
# Number of Columns/Attributes in the data frame is: 46

# %%
# Get the column types of the earth_quake_data

earth_quake_data.dtypes
# Out:
# DisNo.                                        object
# Historic                                      object
# Classification Key                            object
# Disaster Group                                object
# Disaster Subgroup                             object
# Disaster Type                                 object
# Disaster Subtype                              object
# External IDs                                  object
# Event Name                                   float64
# ISO                                           object
# Country                                       object
# Subregion                                     object
# Region                                        object
# Location                                      object
# Origin                                        object
# Associated Types                              object
# OFDA/BHA Response                             object
# Appeal                                        object
# ...

# %%
# Reading the 'Drought_SouthAsianData2000to2020.csv' data
# Store the result in a variable called drought_data

drought_data = pd.read_csv('Drought_SouthAsianData2000to2020.csv')
drought_data.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-9186-AFG       No    nat-cli-dro-dro        Natural    Climatological
# 1  2000-9222-IND       No    nat-cli-dro-dro        Natural    Climatological
# 2  2001-9498-LKA       No    nat-cli-dro-dro        Natural    Climatological
# 3  2002-9349-IND       No    nat-cli-dro-dro        Natural    Climatological
# 4  2006-9570-AFG       No    nat-cli-dro-dro        Natural    Climatological
#
#   Disaster Type Disaster Subtype External IDs  Event Name  ISO  ...  \
# 0       Drought          Drought          NaN         NaN  AFG  ...
# 1       Drought          Drought          NaN         NaN  IND  ...
# 2       Drought          Drought          NaN         NaN  LKA  ...
# 3       Drought          Drought          NaN         NaN  IND  ...
# 4       Drought          Drought          NaN         NaN  AFG  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# ...

# %%
# Get the shape of the drought_data

print('Number of Rows/Records are:', drought_data.shape[0])
print('Number of Columns/Attributes are:', drought_data.shape[1])
# Out:
# Number of Rows/Records are: 19
# Number of Columns/Attributes are: 46

# %%
# Get the Names of the Columns of the data frame drought_data

drought_data.columns.values
# Out:
# array(['DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype',
#        'External IDs', 'Event Name', 'ISO', 'Country', 'Subregion',
#        'Region', 'Location', 'Origin', 'Associated Types',
#        'OFDA/BHA Response', 'Appeal', 'Declaration',
#        "AID Contribution ('000 US$)", 'Magnitude', 'Magnitude Scale',
#        'Latitude', 'Longitude', 'River Basin', 'Start Year',
#        'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day',
#        'Total Deaths', 'No. Injured', 'No. Affected', 'No. Homeless',
#        'Total Affected', "Reconstruction Costs ('000 US$)",
#        "Reconstruction Costs, Adjusted ('000 US$)",
#        "Insured Damage ('000 US$)", "Insured Damage, Adjusted ('000 US$)",
#        "Total Damage ('000 US$)", "Total Damage, Adjusted ('000 US$)",
#        'CPI', 'Admin Units', 'Entry Date', 'Last Update'], dtype=object)

# %%
# Get the column types of the drought_data data frame

drought_data.dtypes
# Out:
# DisNo.                                        object
# Historic                                      object
# Classification Key                            object
# Disaster Group                                object
# Disaster Subgroup                             object
# Disaster Type                                 object
# Disaster Subtype                              object
# External IDs                                  object
# Event Name                                   float64
# ISO                                           object
# Country                                       object
# Subregion                                     object
# Region                                        object
# Location                                      object
# Origin                                        object
# Associated Types                              object
# OFDA/BHA Response                             object
# Appeal                                        object
# ...

# %%
# Reading the 'Flood_SouthAsianData2000to2020.csv' data
# Store the result in a variable called flood_data

flood_data = pd.read_csv('Flood_SouthAsianData2000to2020.csv')
flood_data.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-0332-IND       No    nat-hyd-flo-fla        Natural      Hydrological
# 1  2000-0373-BGD       No    nat-hyd-flo-fla        Natural      Hydrological
# 2  2000-0444-IND       No    nat-hyd-flo-fla        Natural      Hydrological
# 3  2000-0445-IND       No    nat-hyd-flo-riv        Natural      Hydrological
# 4  2000-0476-NPL       No    nat-hyd-flo-flo        Natural      Hydrological
#
#   Disaster Type Disaster Subtype External IDs  Event Name  ISO  ...  \
# 0         Flood      Flash flood          NaN         NaN  IND  ...
# 1         Flood      Flash flood          NaN         NaN  BGD  ...
# 2         Flood      Flash flood          NaN         NaN  IND  ...
# 3         Flood   Riverine flood          NaN         NaN  IND  ...
# 4         Flood  Flood (General)          NaN         NaN  NPL  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# ...

# %%
# Get the shape of the flood_data data frame

print('The number of Records/Rows are:', flood_data.shape[0])
print('The number of Column/Attrubutes are:', flood_data.shape[1])
# Out:
# The number of Records/Rows are: 477
# The number of Column/Attrubutes are: 46

# %%
# Get the column names of the data frame flood_data

flood_data.columns.values
# Out:
# array(['DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype',
#        'External IDs', 'Event Name', 'ISO', 'Country', 'Subregion',
#        'Region', 'Location', 'Origin', 'Associated Types',
#        'OFDA/BHA Response', 'Appeal', 'Declaration',
#        "AID Contribution ('000 US$)", 'Magnitude', 'Magnitude Scale',
#        'Latitude', 'Longitude', 'River Basin', 'Start Year',
#        'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day',
#        'Total Deaths', 'No. Injured', 'No. Affected', 'No. Homeless',
#        'Total Affected', "Reconstruction Costs ('000 US$)",
#        "Reconstruction Costs, Adjusted ('000 US$)",
#        "Insured Damage ('000 US$)", "Insured Damage, Adjusted ('000 US$)",
#        "Total Damage ('000 US$)", "Total Damage, Adjusted ('000 US$)",
#        'CPI', 'Admin Units', 'Entry Date', 'Last Update'], dtype=object)

# %%
# Get the column types of the flood_data data frame

flood_data.dtypes
# Out:
# DisNo.                                        object
# Historic                                      object
# Classification Key                            object
# Disaster Group                                object
# Disaster Subgroup                             object
# Disaster Type                                 object
# Disaster Subtype                              object
# External IDs                                  object
# Event Name                                   float64
# ISO                                           object
# Country                                       object
# Subregion                                     object
# Region                                        object
# Location                                      object
# Origin                                        object
# Associated Types                              object
# OFDA/BHA Response                             object
# Appeal                                        object
# ...

# %%
# Reading the 'Storm_SouthAsianData2000to2020.csv' data
# Store the result in a variable called storm_data

storm_data = pd.read_csv('Storm_SouthAsianData2000to2020.csv')
storm_data.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-0009-IRN       No    nat-met-sto-sto        Natural    Meteorological
# 1  2000-0146-BGD       No    nat-met-sto-tor        Natural    Meteorological
# 2  2000-0211-BGD       No    nat-met-sto-tro        Natural    Meteorological
# 3  2000-0229-BGD       No    nat-met-sto-tro        Natural    Meteorological
# 4  2000-0283-BGD       No    nat-met-sto-sto        Natural    Meteorological
#
#   Disaster Type  Disaster Subtype External IDs Event Name  ISO  ...  \
# 0         Storm   Storm (General)          NaN        NaN  IRN  ...
# 1         Storm           Tornado          NaN        NaN  BGD  ...
# 2         Storm  Tropical cyclone          NaN        NaN  BGD  ...
# 3         Storm  Tropical cyclone          NaN        NaN  BGD  ...
# 4         Storm   Storm (General)          NaN        NaN  BGD  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# ...

# %%
# Get the shape of the storm_data data frame

print('Number of Rows/Records in the data frame is:', storm_data.shape[0])
print('Number of Columns/Attributes in the data frame is:', storm_data.shape[1])
# Out:
# Number of Rows/Records in the data frame is: 185
# Number of Columns/Attributes in the data frame is: 46

# %%
# Get the column names of the data frame storm_data

storm_data.columns.values
# Out:
# array(['DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype',
#        'External IDs', 'Event Name', 'ISO', 'Country', 'Subregion',
#        'Region', 'Location', 'Origin', 'Associated Types',
#        'OFDA/BHA Response', 'Appeal', 'Declaration',
#        "AID Contribution ('000 US$)", 'Magnitude', 'Magnitude Scale',
#        'Latitude', 'Longitude', 'River Basin', 'Start Year',
#        'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day',
#        'Total Deaths', 'No. Injured', 'No. Affected', 'No. Homeless',
#        'Total Affected', "Reconstruction Costs ('000 US$)",
#        "Reconstruction Costs, Adjusted ('000 US$)",
#        "Insured Damage ('000 US$)", "Insured Damage, Adjusted ('000 US$)",
#        "Total Damage ('000 US$)", "Total Damage, Adjusted ('000 US$)",
#        'CPI', 'Admin Units', 'Entry Date', 'Last Update'], dtype=object)

# %%
# Get the column types of the data frame storm_data

storm_data.dtypes
# Out:
# DisNo.                                        object
# Historic                                      object
# Classification Key                            object
# Disaster Group                                object
# Disaster Subgroup                             object
# Disaster Type                                 object
# Disaster Subtype                              object
# External IDs                                  object
# Event Name                                    object
# ISO                                           object
# Country                                       object
# Subregion                                     object
# Region                                        object
# Location                                      object
# Origin                                        object
# Associated Types                              object
# OFDA/BHA Response                             object
# Appeal                                        object
# ...

# %% [markdown]
# ### We observe that each of the 4 data frames have same number of columns and explicitely same columns
#
# * I join the 4 data frames to form a full complete data frame
# * Store the complete data in an object called finaldata
# * I name the complete data frame as 'FourDisaster_SouthAsianData2000to2024.csv'

# %%
# Concatinate the four data frame objects and check the shape

final_data = pd.concat([storm_data, flood_data, earth_quake_data,drought_data], axis = 0)

# Check the Shape of the data frame objcet final_data
print('Number of Rows in final_data are:', final_data.shape[0])
print('Number of Columns in final_data are:', final_data.shape[1])
# Out:
# Number of Rows in final_data are: 781
# Number of Columns in final_data are: 46

# %%
# Check the first few rows of the final_data data frame object

final_data.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-0009-IRN       No    nat-met-sto-sto        Natural    Meteorological
# 1  2000-0146-BGD       No    nat-met-sto-tor        Natural    Meteorological
# 2  2000-0211-BGD       No    nat-met-sto-tro        Natural    Meteorological
# 3  2000-0229-BGD       No    nat-met-sto-tro        Natural    Meteorological
# 4  2000-0283-BGD       No    nat-met-sto-sto        Natural    Meteorological
#
#   Disaster Type  Disaster Subtype External IDs Event Name  ISO  ...  \
# 0         Storm   Storm (General)          NaN        NaN  IRN  ...
# 1         Storm           Tornado          NaN        NaN  BGD  ...
# 2         Storm  Tropical cyclone          NaN        NaN  BGD  ...
# 3         Storm  Tropical cyclone          NaN        NaN  BGD  ...
# 4         Storm   Storm (General)          NaN        NaN  BGD  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# ...

# %%
# Exporting the final_data as 'FourDisaster_SouthAsianData2000to2020csv'

filepath = 'FourDisaster_SouthAsianData2000to2020.csv'
final_data.to_csv(filepath, index = False)
